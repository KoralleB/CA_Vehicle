# %%
import sys
import os
import numpy as np

module_path = os.path.abspath(os.path.join('..'))

if module_path not in sys.path:
    sys.path.append(module_path+"\\code")

from model_plot import roc_plot
from model_plot import pr_plot
from model_plot import conf_mat
from model_plot import var_imp

# %%
fpr_rf, tpr_rf = np.load('../export_files/fpr_rf.npy'),np.load('../export_files/tpr_rf.npy')
roc_auc_rf = np.load('../export_files/roc_auc_rf.npy')

label = ['rf']
fpr = [fpr_rf]
tpr = [tpr_rf]
roc_auc = [roc_auc_rf]
roc_plot(label,fpr,tpr,roc_auc)

# %%
precision_rf, recall_rf = np.load('../export_files/precision_rf.npy'),np.load('../export_files/recall_rf.npy')

label_pr = ['rf']
recall = [recall_rf]
precision = [precision_rf]

pr_plot(label_pr,recall,precision)

# %%
conf_mat(np.load('../export_files/cm_rf.npy'))
# Out:
#       ICEV   EV
# ICEV  4229  255
# EV     150   35

# %%
var_imp(10)
